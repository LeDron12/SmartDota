# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests

mathes_batch = requests.get(
                    url = "https://api.opendota.com/api" + '/proMatches/',
                    params = {
                        'api_key': 'e881de34-fef0-4d0e-8e45-851c569ba3a2',
                        'less_than_match_id': 7473541663
                    }
                ).json()
print(mathes_batch)
mathes_batch[0]
# Out:
# [{'match_id': 7473541662, 'duration': 2058, 'start_time': 1701772291, 'radiant_team_id': 8254145, 'radiant_name': 'Execration', 'dire_team_id': 9264957, 'dire_name': 'Me Parb', 'leagueid': 15900, 'league_name': 'EPL World Series: Southeast Asia 2023-2024 Season ', 'series_id': 832417, 'series_type': 1, 'radiant_score': 34, 'dire_score': 10, 'radiant_win': True, 'version': 21}, {'match_id': 7473538484, 'duration': 1509, 'start_time': 1701771593, 'radiant_team_id': 8629318, 'radiant_name': 'Mad Monkeys', 'dire_team_id': 8629317, 'dire_name': 'Bright Crusaders', 'leagueid': 15716, 'league_name': 'Destiny league', 'series_id': 832416, 'series_type': 1, 'radiant_score': 16, 'dire_score': 31, 'radiant_win': False, 'version': 21}, {'match_id': 7473527416, 'duration': 3628, 'start_time': 1701770890, 'radiant_team_id': 8829924, 'radiant_name': 'Rabbits of Revenge', 'dire_team_id': 8831040, 'dire_name': 'Ghost Sheep', 'leagueid': 15901, 'league_name': 'Ultras Dota Pro League  2023-24', 'series_id': 832411, 'series_type': 1, 'radiant_score': 35, 'dire_score': 53, 'radiant_win': False, 'version': 21}, {'match_id': 7473499725, 'duration': 2109, 'start_time': 1701769105, 'radiant_team_id': 8893840, 'radiant_name': 'Big Bang Gaming', 'dire_team_id': 8893837, 'dire_name': 'Parallel eSports', 'leagueid': 15819, 'league_name': 'Ancients League', 'series_id': 832413, 'series_type': 1, 'radiant_score': 38, 'dire_score': 33, 'radiant_win': True, 'version': 21}, {'match_id': 7473496660, 'duration': 1806, 'start_time': 1701768978, 'radiant_team_id': 8629324, 'radiant_name': 'Swift Knights', 'dire_team_id': 8629327, 'dire_name': 'Sworn Die', 'leagueid': 15716, 'league_name': 'Destiny league', 'series_id': 832407, 'series_type': 1, 'radiant_score': 16, 'dire_score': 46, 'radiant_win': False, 'version': 21}, {'match_id': 7473485471, 'duration': 2658, 'start_time': 1701768147, 'radiant_team_id': 9109275, 'radiant_name': 'PullUp', 'dire_team_id': 9256255, 'dire_name': 'Amanita', 'leagueid': 15857, 'league_name': 'ESportsBattle | DOTA2 WC6', 'series_id': 832412, 'series_type': 1, 'radiant_score': 37, 'dire_score': 41, 'radiant_win': False, 'version': 21}, {'match_id': 7473483063, 'duration': 2417, 'start_time': 1701768097, 'radiant_team_id': 8736661, 'radiant_name': 'Made in Philippines', 'dire_team_id': 8597976, 'dire_name': 'Talon', 'leagueid': 15900, 'league_name': 'EPL World Series: Southeast Asia 2023-2024 Season ', 'series_id': 832403, 'series_type': 1, 'radiant_score': 28, 'dire_score': 49, 'radiant_win': False, 'version': 21}, {'match_id': 7473476982, 'duration': 2152, 'start_time': 1701767689, 'radiant_team_id': 8831040, 'radiant_name': 'Ghost Sheep', 'dire_team_id': 8829924, 'dire_name': 'Rabbits of Revenge', 'leagueid': 15901, 'league_name': 'Ultras Dota Pro League  2023-24', 'series_id': 832411, 'series_type': 1, 'radiant_score': 36, 'dire_score': 29, 'radiant_win': True, 'version': 21}, {'match_id': 7473467291, 'duration': 1534, 'start_time': 1701766916, 'radiant_team_id': 8936507, 'radiant_name': 'FenixTeam', 'dire_team_id': 9018543, 'dire_name': 'Hustlers', 'leagueid': 15819, 'league_name': 'Ancients League', 'series_id': 832405, 'series_type': 1, 'radiant_score': 38, 'dire_score': 26, 'radiant_win': True, 'version': 21}, {'match_id': 7473464502, 'duration': 1519, 'start_time': 1701766810, 'radiant_team_id': 9247664, 'radiant_name': 'Eagle', 'dire_team_id': 9247630, 'dire_name': 'Go along', 'leagueid': 15960, 'league_name': 'Electro Dilemma | Cringe Station', 'series_id': 832409, 'series_type': 1, 'radiant_score': 9, 'dire_score': 23, 'radiant_win': False, 'version': 21}, {'match_id': 7473459007, 'duration': 1859, 'start_time': 1701766383, 'radiant_team_id': 8629327, 'radiant_name': 'Sworn Die', 'dire_team_id': 8629324, 'dire_name': 'Swift Knights', 'leagueid': 15716, 'league_name': 'Destiny league', 'series_id': 832407, 'series_type': 1, 'radiant_score': 16, 'dire_score': 31, 'radiant_win': False, 'version': 21}, {'match_id': 7473435335, ' ...
# {'match_id': 7473541662,
#  'duration': 2058,
#  'start_time': 1701772291,
#  'radiant_team_id': 8254145,
#  'radiant_name': 'Execration',
#  'dire_team_id': 9264957,
#  'dire_name': 'Me Parb',
#  'leagueid': 15900,
#  'league_name': 'EPL World Series: Southeast Asia 2023-2024 Season ',
#  'series_id': 832417,
#  'series_type': 1,
#  'radiant_score': 34,
#  'dire_score': 10,
#  'radiant_win': True,
#  'version': 21}

# %%
heroes = requests.get(
            url = 'https://api.opendota.com/api/heroes',
            params = {
                'api_key': 'e881de34-fef0-4d0e-8e45-851c569ba3a2'
            }
        ).json()
heroes
# Out:
# [{'id': 1,
#   'name': 'npc_dota_hero_antimage',
#   'localized_name': 'Anti-Mage',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 2,
#   'name': 'npc_dota_hero_axe',
#   'localized_name': 'Axe',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Carry'],
#   'legs': None},
#  {'id': 3,
#   'name': 'npc_dota_hero_bane',
#   'localized_name': 'Bane',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Durable'],
#   'legs': None},
#  {'id': 4,
#   'name': 'npc_dota_hero_bloodseeker',
#   'localized_name': 'Bloodseeker',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': None},
#  {'id': 5,
#   'name': 'npc_dota_hero_crystal_maiden',
#   'localized_name': 'Crystal Maiden',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 6,
#   'name': 'npc_dota_hero_drow_ranger',
#   'localized_name': 'Drow Ranger',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Pusher'],
#   'legs': None},
#  {'id': 7,
#   'name': 'npc_dota_hero_earthshaker',
#   'localized_name': 'Earthshaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 8,
#   'name': 'npc_dota_hero_juggernaut',
#   'localized_name': 'Juggernaut',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape'],
#   'legs': None},
#  {'id': 9,
#   'name': 'npc_dota_hero_mirana',
#   'localized_name': 'Mirana',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Escape', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 10,
#   'name': 'npc_dota_hero_morphling',
#   'localized_name': 'Morphling',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Durable', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 11,
#   'name': 'npc_dota_hero_nevermore',
#   'localized_name': 'Shadow Fiend',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'legs': None},
#  {'id': 12,
#   'name': 'npc_dota_hero_phantom_lancer',
#   'localized_name': 'Phantom Lancer',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Pusher', 'Nuker'],
#   'legs': None},
#  {'id': 13,
#   'name': 'npc_dota_hero_puck',
#   'localized_name': 'Puck',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 14,
#   'name': 'npc_dota_hero_pudge',
#   'localized_name': 'Pudge',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 15,
#   'name': 'npc_dota_hero_razor',
#   'localized_name': 'Razor',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Nuker', 'Pusher'],
#   'legs': None},
#  {'id': 16,
#   'name': 'npc_dota_hero_sand_king',
#   'localized_name': 'Sand King',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Support', 'Nuker', 'Escape'],
#   'legs': None},
#  {'id': 17,
#   'name': 'npc_dota_hero_storm_spirit',
#   'localized_name': 'Storm Spirit',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Initiator', 'Disabler'],
#   'legs': None},
#  {'id': 18,
#   'name': 'npc_dota_hero_sven',
#   'localized_name': 'Sven',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 19,
#   'name': 'npc_dota_hero_tiny',
#   'localized_name': 'Tiny',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Pusher', 'Initiator', 'Durable', 'Disabler'],
#   'legs': None},
#  {'id': 20,
#   'name': 'npc_dota_hero_vengefulspirit',
#   'localized_name': 'Vengeful Spirit',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': None},
#  {'id': 21,
#   'name': 'npc_dota_hero_windrunner',
#   'localized_name': 'Windranger',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 22,
#   'name': 'npc_dota_hero_zuus',
#   'localized_name': 'Zeus',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Carry'],
#   'legs': None},
#  {'id': 23,
#   'name': 'npc_dota_hero_kunkka',
#   'localized_name': 'Kunkka',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 25,
#   'name': 'npc_dota_hero_lina',
#   'localized_name': 'Lina',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Carry', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 26,
#   'name': 'npc_dota_hero_lion',
#   'localized_name': 'Lion',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': None},
#  {'id': 27,
#   'name': 'npc_dota_hero_shadow_shaman',
#   'localized_name': 'Shadow Shaman',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': None},
#  {'id': 28,
#   'name': 'npc_dota_hero_slardar',
#   'localized_name': 'Slardar',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 29,
#   'name': 'npc_dota_hero_tidehunter',
#   'localized_name': 'Tidehunter',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Nuker', 'Carry'],
#   'legs': None},
#  {'id': 30,
#   'name': 'npc_dota_hero_witch_doctor',
#   'localized_name': 'Witch Doctor',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 31,
#   'name': 'npc_dota_hero_lich',
#   'localized_name': 'Lich',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker'],
#   'legs': None},
#  {'id': 32,
#   'name': 'npc_dota_hero_riki',
#   'localized_name': 'Riki',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'legs': None},
#  {'id': 33,
#   'name': 'npc_dota_hero_enigma',
#   'localized_name': 'Enigma',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Disabler', 'Initiator', 'Pusher'],
#   'legs': None},
#  {'id': 34,
#   'name': 'npc_dota_hero_tinker',
#   'localized_name': 'Tinker',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'legs': None},
#  {'id': 35,
#   'name': 'npc_dota_hero_sniper',
#   'localized_name': 'Sniper',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'legs': None},
#  {'id': 36,
#   'name': 'npc_dota_hero_necrolyte',
#   'localized_name': 'Necrophos',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Durable', 'Disabler'],
#   'legs': None},
#  {'id': 37,
#   'name': 'npc_dota_hero_warlock',
#   'localized_name': 'Warlock',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler'],
#   'legs': None},
#  {'id': 38,
#   'name': 'npc_dota_hero_beastmaster',
#   'localized_name': 'Beastmaster',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 39,
#   'name': 'npc_dota_hero_queenofpain',
#   'localized_name': 'Queen of Pain',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Escape'],
#   'legs': None},
#  {'id': 40,
#   'name': 'npc_dota_hero_venomancer',
#   'localized_name': 'Venomancer',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Pusher', 'Disabler'],
#   'legs': None},
#  {'id': 41,
#   'name': 'npc_dota_hero_faceless_void',
#   'localized_name': 'Faceless Void',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Escape', 'Durable'],
#   'legs': None},
#  {'id': 42,
#   'name': 'npc_dota_hero_skeleton_king',
#   'localized_name': 'Wraith King',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator'],
#   'legs': None},
#  {'id': 43,
#   'name': 'npc_dota_hero_death_prophet',
#   'localized_name': 'Death Prophet',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 44,
#   'name': 'npc_dota_hero_phantom_assassin',
#   'localized_name': 'Phantom Assassin',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape'],
#   'legs': None},
#  {'id': 45,
#   'name': 'npc_dota_hero_pugna',
#   'localized_name': 'Pugna',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Pusher'],
#   'legs': None},
#  {'id': 46,
#   'name': 'npc_dota_hero_templar_assassin',
#   'localized_name': 'Templar Assassin',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'legs': None},
#  {'id': 47,
#   'name': 'npc_dota_hero_viper',
#   'localized_name': 'Viper',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler'],
#   'legs': None},
#  {'id': 48,
#   'name': 'npc_dota_hero_luna',
#   'localized_name': 'Luna',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'legs': None},
#  {'id': 49,
#   'name': 'npc_dota_hero_dragon_knight',
#   'localized_name': 'Dragon Knight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': None},
#  {'id': 50,
#   'name': 'npc_dota_hero_dazzle',
#   'localized_name': 'Dazzle',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 51,
#   'name': 'npc_dota_hero_rattletrap',
#   'localized_name': 'Clockwerk',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 52,
#   'name': 'npc_dota_hero_leshrac',
#   'localized_name': 'Leshrac',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Nuker', 'Pusher', 'Disabler'],
#   'legs': 4},
#  {'id': 53,
#   'name': 'npc_dota_hero_furion',
#   'localized_name': "Nature's Prophet",
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 54,
#   'name': 'npc_dota_hero_life_stealer',
#   'localized_name': 'Lifestealer',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape', 'Disabler'],
#   'legs': None},
#  {'id': 55,
#   'name': 'npc_dota_hero_dark_seer',
#   'localized_name': 'Dark Seer',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Escape', 'Disabler'],
#   'legs': None},
#  {'id': 56,
#   'name': 'npc_dota_hero_clinkz',
#   'localized_name': 'Clinkz',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Pusher'],
#   'legs': None},
#  {'id': 57,
#   'name': 'npc_dota_hero_omniknight',
#   'localized_name': 'Omniknight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 58,
#   'name': 'npc_dota_hero_enchantress',
#   'localized_name': 'Enchantress',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Durable', 'Disabler'],
#   'legs': None},
#  {'id': 59,
#   'name': 'npc_dota_hero_huskar',
#   'localized_name': 'Huskar',
#   'primary_attr': 'str',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator'],
#   'legs': None},
#  {'id': 60,
#   'name': 'npc_dota_hero_night_stalker',
#   'localized_name': 'Night Stalker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 61,
#   'name': 'npc_dota_hero_broodmother',
#   'localized_name': 'Broodmother',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 62,
#   'name': 'npc_dota_hero_bounty_hunter',
#   'localized_name': 'Bounty Hunter',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Escape', 'Nuker'],
#   'legs': None},
#  {'id': 63,
#   'name': 'npc_dota_hero_weaver',
#   'localized_name': 'Weaver',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'legs': None},
#  {'id': 64,
#   'name': 'npc_dota_hero_jakiro',
#   'localized_name': 'Jakiro',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Pusher', 'Disabler'],
#   'legs': None},
#  {'id': 65,
#   'name': 'npc_dota_hero_batrider',
#   'localized_name': 'Batrider',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 66,
#   'name': 'npc_dota_hero_chen',
#   'localized_name': 'Chen',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher'],
#   'legs': None},
#  {'id': 67,
#   'name': 'npc_dota_hero_spectre',
#   'localized_name': 'Spectre',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape'],
#   'legs': None},
#  {'id': 68,
#   'name': 'npc_dota_hero_ancient_apparition',
#   'localized_name': 'Ancient Apparition',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 69,
#   'name': 'npc_dota_hero_doom_bringer',
#   'localized_name': 'Doom',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 70,
#   'name': 'npc_dota_hero_ursa',
#   'localized_name': 'Ursa',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Disabler'],
#   'legs': None},
#  {'id': 71,
#   'name': 'npc_dota_hero_spirit_breaker',
#   'localized_name': 'Spirit Breaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable', 'Escape'],
#   'legs': None},
#  {'id': 72,
#   'name': 'npc_dota_hero_gyrocopter',
#   'localized_name': 'Gyrocopter',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 73,
#   'name': 'npc_dota_hero_alchemist',
#   'localized_name': 'Alchemist',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': None},
#  {'id': 74,
#   'name': 'npc_dota_hero_invoker',
#   'localized_name': 'Invoker',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Escape', 'Pusher'],
#   'legs': None},
#  {'id': 75,
#   'name': 'npc_dota_hero_silencer',
#   'localized_name': 'Silencer',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': None},
#  {'id': 76,
#   'name': 'npc_dota_hero_obsidian_destroyer',
#   'localized_name': 'Outworld Destroyer',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 77,
#   'name': 'npc_dota_hero_lycan',
#   'localized_name': 'Lycan',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Escape'],
#   'legs': None},
#  {'id': 78,
#   'name': 'npc_dota_hero_brewmaster',
#   'localized_name': 'Brewmaster',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 79,
#   'name': 'npc_dota_hero_shadow_demon',
#   'localized_name': 'Shadow Demon',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': None},
#  {'id': 80,
#   'name': 'npc_dota_hero_lone_druid',
#   'localized_name': 'Lone Druid',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Durable'],
#   'legs': None},
#  {'id': 81,
#   'name': 'npc_dota_hero_chaos_knight',
#   'localized_name': 'Chaos Knight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Durable', 'Pusher', 'Initiator'],
#   'legs': None},
#  {'id': 82,
#   'name': 'npc_dota_hero_meepo',
#   'localized_name': 'Meepo',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator', 'Pusher'],
#   'legs': None},
#  {'id': 83,
#   'name': 'npc_dota_hero_treant',
#   'localized_name': 'Treant Protector',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Durable', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 84,
#   'name': 'npc_dota_hero_ogre_magi',
#   'localized_name': 'Ogre Magi',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Initiator'],
#   'legs': None},
#  {'id': 85,
#   'name': 'npc_dota_hero_undying',
#   'localized_name': 'Undying',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 86,
#   'name': 'npc_dota_hero_rubick',
#   'localized_name': 'Rubick',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 87,
#   'name': 'npc_dota_hero_disruptor',
#   'localized_name': 'Disruptor',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': None},
#  {'id': 88,
#   'name': 'npc_dota_hero_nyx_assassin',
#   'localized_name': 'Nyx Assassin',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Nuker', 'Initiator', 'Escape'],
#   'legs': None},
#  {'id': 89,
#   'name': 'npc_dota_hero_naga_siren',
#   'localized_name': 'Naga Siren',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Pusher', 'Disabler', 'Initiator', 'Escape'],
#   'legs': None},
#  {'id': 90,
#   'name': 'npc_dota_hero_keeper_of_the_light',
#   'localized_name': 'Keeper of the Light',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 91,
#   'name': 'npc_dota_hero_wisp',
#   'localized_name': 'Io',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 92,
#   'name': 'npc_dota_hero_visage',
#   'localized_name': 'Visage',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Durable', 'Disabler', 'Pusher'],
#   'legs': None},
#  {'id': 93,
#   'name': 'npc_dota_hero_slark',
#   'localized_name': 'Slark',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 94,
#   'name': 'npc_dota_hero_medusa',
#   'localized_name': 'Medusa',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Durable'],
#   'legs': None},
#  {'id': 95,
#   'name': 'npc_dota_hero_troll_warlord',
#   'localized_name': 'Troll Warlord',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Disabler', 'Durable'],
#   'legs': None},
#  {'id': 96,
#   'name': 'npc_dota_hero_centaur',
#   'localized_name': 'Centaur Warrunner',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Durable', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': None},
#  {'id': 97,
#   'name': 'npc_dota_hero_magnataur',
#   'localized_name': 'Magnus',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': None},
#  {'id': 98,
#   'name': 'npc_dota_hero_shredder',
#   'localized_name': 'Timbersaw',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Durable', 'Escape'],
#   'legs': None},
#  {'id': 99,
#   'name': 'npc_dota_hero_bristleback',
#   'localized_name': 'Bristleback',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Nuker'],
#   'legs': None},
#  {'id': 100,
#   'name': 'npc_dota_hero_tusk',
#   'localized_name': 'Tusk',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 101,
#   'name': 'npc_dota_hero_skywrath_mage',
#   'localized_name': 'Skywrath Mage',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 102,
#   'name': 'npc_dota_hero_abaddon',
#   'localized_name': 'Abaddon',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Durable'],
#   'legs': None},
#  {'id': 103,
#   'name': 'npc_dota_hero_elder_titan',
#   'localized_name': 'Elder Titan',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Durable'],
#   'legs': None},
#  {'id': 104,
#   'name': 'npc_dota_hero_legion_commander',
#   'localized_name': 'Legion Commander',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': None},
#  {'id': 105,
#   'name': 'npc_dota_hero_techies',
#   'localized_name': 'Techies',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 106,
#   'name': 'npc_dota_hero_ember_spirit',
#   'localized_name': 'Ember Spirit',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator'],
#   'legs': None},
#  {'id': 107,
#   'name': 'npc_dota_hero_earth_spirit',
#   'localized_name': 'Earth Spirit',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Escape', 'Disabler', 'Initiator', 'Durable'],
#   'legs': None},
#  {'id': 108,
#   'name': 'npc_dota_hero_abyssal_underlord',
#   'localized_name': 'Underlord',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Escape'],
#   'legs': None},
#  {'id': 109,
#   'name': 'npc_dota_hero_terrorblade',
#   'localized_name': 'Terrorblade',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Nuker'],
#   'legs': None},
#  {'id': 110,
#   'name': 'npc_dota_hero_phoenix',
#   'localized_name': 'Phoenix',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Escape', 'Disabler'],
#   'legs': None},
#  {'id': 111,
#   'name': 'npc_dota_hero_oracle',
#   'localized_name': 'Oracle',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': 0},
#  {'id': 112,
#   'name': 'npc_dota_hero_winter_wyvern',
#   'localized_name': 'Winter Wyvern',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': None},
#  {'id': 113,
#   'name': 'npc_dota_hero_arc_warden',
#   'localized_name': 'Arc Warden',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'legs': None},
#  {'id': 114,
#   'name': 'npc_dota_hero_monkey_king',
#   'localized_name': 'Monkey King',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Initiator'],
#   'legs': None},
#  {'id': 119,
#   'name': 'npc_dota_hero_dark_willow',
#   'localized_name': 'Dark Willow',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 120,
#   'name': 'npc_dota_hero_pangolier',
#   'localized_name': 'Pangolier',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator'],
#   'legs': None},
#  {'id': 121,
#   'name': 'npc_dota_hero_grimstroke',
#   'localized_name': 'Grimstroke',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 123,
#   'name': 'npc_dota_hero_hoodwink',
#   'localized_name': 'Hoodwink',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Escape', 'Disabler'],
#   'legs': None},
#  {'id': 126,
#   'name': 'npc_dota_hero_void_spirit',
#   'localized_name': 'Void Spirit',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler'],
#   'legs': None},
#  {'id': 128,
#   'name': 'npc_dota_hero_snapfire',
#   'localized_name': 'Snapfire',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 129,
#   'name': 'npc_dota_hero_mars',
#   'localized_name': 'Mars',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable'],
#   'legs': None},
#  {'id': 135,
#   'name': 'npc_dota_hero_dawnbreaker',
#   'localized_name': 'Dawnbreaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable'],
#   'legs': None},
#  {'id': 136,
#   'name': 'npc_dota_hero_marci',
#   'localized_name': 'Marci',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Initiator', 'Disabler', 'Escape'],
#   'legs': None},
#  {'id': 137,
#   'name': 'npc_dota_hero_primal_beast',
#   'localized_name': 'Primal Beast',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler'],
#   'legs': None},
#  {'id': 138,
#   'name': 'npc_dota_hero_muerta',
#   'localized_name': 'Muerta',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': None}]

# %%
import json

with open('/home/ankamenskiy/SmartDota/data/heroes.json', 'w') as f:
    f.write(json.dumps(heroes))

# %%
team = requests.get(
                    url = "https://api.opendota.com/api" + '/teams/8254145'
                ).json()
team
# Out:
# {'team_id': 8254145,
#  'rating': 1307.14,
#  'wins': 447,
#  'losses': 381,
#  'last_match_time': 1701772291,
#  'name': 'Execration',
#  'tag': 'XctN',
#  'logo_url': 'https://steamusercontent-a.akamaihd.net/ugc/2024966396057134788/4EE29568BB91ECB5E77FC61824B6264789485060/'}

# %%
match = requests.get(
                    url = "https://api.opendota.com/api/matches/" + '7472054974'
                ).json()
match['win']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> match = requests.get(
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>                     url = "https://api.opendota.com/api/matches/" + '7472054974'
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>                 ).json()
# ----> <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> match['win']
#
# KeyError: 'win'

# %%
match = requests.get(
                    url = "https://api.opendota.com/api/matches/" + '7472080788'
                ).json()
match['win']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> match = requests.get(
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>                     url = "https://api.opendota.com/api/matches/" + '7472080788'
#       <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>                 ).json()
# ----> <a href='vscode-notebook-cell:/Users/ankamenskiy/SmartDota/src/sandbox/test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> match['win']
#
# KeyError: 'win'

# %%
s = {}
for elem in [list(item.items()) for item in match['objectives']]:
    for item in elem:
        s[item[0]] = s.get(item[0], 0) + 1
s
# Out:
# {'time': 11,
#  'type': 11,
#  'slot': 5,
#  'key': 9,
#  'player_slot': 5,
#  'value': 2,
#  'killer': 2,
#  'team': 2,
#  'unit': 8}

# %%
match['draft_timings']
# Out:
# [{'order': 1,
#   'pick': False,
#   'active_team': 2,
#   'hero_id': 137,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 2,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 67,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 3,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 53,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 4,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 54,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 5,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 81,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 6,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 86,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 7,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 50,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 8,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 39,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 9,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 11,
#   'player_slot': None,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 10,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 138,
#   'player_slot': 1,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 11,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 136,
#   'player_slot': 9,
#   'extra_time': 130,
#   'total_time_taken': 0},
#  {'order': 12,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 71,
#   'player_slot': None,
#   'extra_time': 121,
#   'total_time_taken': 33},
#  {'order': 13,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 90,
#   'player_slot': 7,
#   'extra_time': 118,
#   'total_time_taken': 22},
#  {'order': 14,
#   'pick': True,
#   'active_team': 2,
#   'hero_id': 85,
#   'player_slot': 2,
#   'extra_time': 118,
#   'total_time_taken': 15},
#  {'order': 15,
#   'pick': True,
#   'active_team': 2,
#   'hero_id': 30,
#   'player_slot': 3,
#   'extra_time': 121,
#   'total_time_taken': 16},
#  {'order': 16,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 21,
#   'player_slot': 6,
#   'extra_time': 116,
#   'total_time_taken': 35},
#  {'order': 17,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 63,
#   'player_slot': 8,
#   'extra_time': 118,
#   'total_time_taken': 7},
#  {'order': 18,
#   'pick': True,
#   'active_team': 2,
#   'hero_id': 35,
#   'player_slot': 4,
#   'extra_time': 118,
#   'total_time_taken': 2},
#  {'order': 19,
#   'pick': False,
#   'active_team': 2,
#   'hero_id': 106,
#   'player_slot': None,
#   'extra_time': 116,
#   'total_time_taken': 7},
#  {'order': 20,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 42,
#   'player_slot': None,
#   'extra_time': 116,
#   'total_time_taken': 21},
#  {'order': 21,
#   'pick': False,
#   'active_team': 3,
#   'hero_id': 46,
#   'player_slot': None,
#   'extra_time': 118,
#   'total_time_taken': 5},
#  {'order': 22,
#   'pick': False,
#   'active_team': 2,
#   'hero_id': 45,
#   'player_slot': None,
#   'extra_time': 118,
#   'total_time_taken': 30},
#  {'order': 23,
#   'pick': True,
#   'active_team': 2,
#   'hero_id': 51,
#   'player_slot': 0,
#   'extra_time': 116,
#   'total_time_taken': 68},
#  {'order': 24,
#   'pick': True,
#   'active_team': 3,
#   'hero_id': 19,
#   'player_slot': 5,
#   'extra_time': 116,
#   'total_time_taken': 10}]

# %%
# !pwd
# Out:
# /home/ankamenskiy/SmartDota/src/sandbox

# %%
import sys
sys.path.append('/home/ankamenskiy/SmartDota/')

from src.data.api.download import ProMatchesDataloader

TOTAL_AMOUNT = 1_000
# TOTAL_AMOUNT = 10
path = f'../../cache/pro_{TOTAL_AMOUNT}'

downloader = ProMatchesDataloader(1)
matches = downloader(TOTAL_AMOUNT)
downloader.save(path)
downloader.load(path)

print(downloader.data)
# Out:
# Loading pro matches data from OpenDota:   0%|          | 0/1000 [00:00<?, ?it/s]
# PRO MATCHES loaded: 0
# Loading pro matches data from OpenDota:  10%|█         | 100/1000 [00:00<00:04, 210.01it/s]
# PRO MATCHES loaded: 100
# Loading pro matches data from OpenDota:  20%|██        | 200/1000 [00:10<00:50, 15.76it/s]
# PRO MATCHES loaded: 200
# Loading pro matches data from OpenDota:  30%|███       | 300/1000 [00:21<00:57, 12.15it/s]
# PRO MATCHES loaded: 300
# Loading pro matches data from OpenDota:  40%|████      | 400/1000 [00:31<00:54, 10.97it/s]
# PRO MATCHES loaded: 400
# Loading pro matches data from OpenDota:  50%|█████     | 500/1000 [00:42<00:48, 10.41it/s]
# PRO MATCHES loaded: 500
# Loading pro matches data from OpenDota:  60%|██████    | 600/1000 [00:52<00:39, 10.11it/s]
# PRO MATCHES loaded: 600
# Loading pro matches data from OpenDota:  70%|███████   | 700/1000 [01:03<00:30,  9.92it/s]
# PRO MATCHES loaded: 700
# Loading pro matches data from OpenDota:  80%|████████  | 800/1000 [01:13<00:20,  9.81it/s]
# PRO MATCHES loaded: 800
# Loading pro matches data from OpenDota:  90%|█████████ | 900/1000 [01:24<00:10,  9.74it/s]
# PRO MATCHES loaded: 900
# Loading pro matches data from OpenDota: 100%|██████████| 1000/1000 [01:44<00:00,  9.56it/s]
# --------------------
# 1000 [ProMatchData(match_id=7569960681, radiant_team_id=8799137, dire_team_id=8367062, leagueid=16078, series_type=1, radiant_score=23, dire_score=17, radiant_win=True), ProMatchData(match_id=7569953309, radiant_team_id=7119077, dire_team_id=8375259, leagueid=15899, series_type=1, radiant_score=29, dire_score=44, radiant_win=False), ProMatchData(match_id=7569939929, radiant_team_id=9005364, dire_team_id=8936613, leagueid=16109, series_type=1, radiant_score=36, dire_score=18, radiant_win=True), ProMatchData(match_id=7569915227, radiant_team_id=8205424, dire_team_id=8702318, leagueid=16078, series_type=0, radiant_score=26, dire_score=36, radiant_win=False), ProMatchData(match_id=7569909495, radiant_team_id=9323233, dire_team_id=8774199, leagueid=16078, series_type=1, radiant_score=22, dire_score=4, radiant_win=True), ProMatchData(match_id=7569908782, radiant_team_id=8367062, dire_team_id=9316627, leagueid=16078, series_type=0, radiant_score=43, dire_score=12, radiant_win=True), ProMatchData(match_id=7569905905, radiant_team_id=8778064, dire_team_id=8180753, leagueid=16078, series_type=0, radiant_score=42, dire_score=30, radiant_win=True), ProMatchData(match_id=7569898626, radiant_team_id=8375259, dire_team_id=7119077, leagueid=15899, series_type=1, radiant_score=33, dire_score=4, radiant_win=True), ProMatchData(match_id=7569896023, radiant_team_id=8936613, dire_team_id=9005364, leagueid=16109, series_type=1, radiant_score=29, dire_score=28, radiant_win=True), ProMatchData(match_id=7569841141, radiant_team_id=9005364, dire_team_id=8936613, leagueid=16109, series_type=1, radiant_score=38, dire_score=31, radiant_win=True), ProMatchData(match_id=7569807712, radiant_team_id=None, dire_team_id=None, leagueid=16079, series_type=None, radiant_score=None, dire_score=None, radiant_win=None), ProMatchData(match_id=7569767419, radiant_team_id=9302841, dire_team_id=9330880, leagueid=15899, series_type=1, radiant_score=39, dire_score=23, radiant_win=True), ProMatchData(match_id=7569667371, radiant_team_id=9302841, dire_team_id=9330880, leagueid=15899, series_type=1, radiant_score=39, dire_score=20, radiant_win=True), ProMatchData(match_id=7569609418, radiant_team_id=9270745, dire_team_id=9088071, leagueid=15901, series_type=1, radiant_score=27, dire_score=35, radiant_win=False), ProMatchData(match_id=7569596341, radiant_team_id=8831040, dire_team_id=9225431, leagueid=15901, series_type=1, radiant_score=37, dire_score=14, radiant_win=True), ProMatchData(match_id=7569594531, radiant_team_id=9322607, dire_team_id=9284751, leagueid=12903, series_type=0, radiant_score=27, dire_score=34, radiant_win=False), ProMatchData(match_id=7569569787, radiant_team_id=9216247, dire_team_id=9081007, leagueid=15898, series_type=1, radiant_score=26, dire_score=49, radiant_win=False), ProMatchData(match_id=7569523430, radiant_team_id=None, dire_team_id=8986987, leagueid=12903, series_type=0, radiant_score=23, dire_score=6, radiant_win=True), ProMatchData(match_id=7569515021, radiant_team_id=9088071, dire_team_id=9270745, leagueid=15901, series_type=1, radiant_score=38, dire_score=52, radiant_win=False), ProMatchData(match_id=7569506573, radiant_team_id=9225431, dire_team_id=8831040, leagueid=15901, series_type=1, radiant_score=22, dire_score=37, radiant_win=False), ProMatchData(match_id=7569466736, radiant_team_id=8728920, dire_team_id=7119388, leagueid=16169, series_type=3, radiant_score=14, dire_score=42, radiant_win=False), ProMatchData(match_id=7569457300, radiant_team_id=9216247, dire_team_id=9081007, leagueid=15898, series_type=1, radiant_score=11, dire_score=31, radiant_win=False), ProMatchData(match_id=7569441549, radiant_team_id=9270745, dire_team_id=9088071, leagueid=15901, series_type=1, radiant_score=23, dire_score=21, radiant_win=False), ProMatchData(match_id=7569440021, radiant_team_id=9247354, dire_team_id=15, leagueid=16169, series_type=3, radiant_score=35, dire_score=6, radiant_win=True), ProMatchData(match_id=7569403148, radiant_team_id=9322607,  ...
# Pro matches loaded
# --------------------
# Loading matches data from OpenDota:   0%|          | 0/1000 [00:00<?, ?it/s]
# TEAMS remained futures: 1000
# Loading teams data from OpenDota: 737it [10:33,  1.16it/s]
# Loading matches data from OpenDota:   0%|          | 0/1000 [10:33<?, ?it/s]

# %%
import json

json.loads('{"team_id":9330880,"rating":969.396,"wins":2,"losses":5,"last_match_time":1707073781,"name":"Stereophonics","tag":"STPH","logo_url":"https://steamusercontent-a.akamaihd.net/ugc/2336873643528563746/DBD2FEC72B30381C07121B1904919A862779DA09/"}')
# Out:
# {'team_id': 9330880,
#  'rating': 969.396,
#  'wins': 2,
#  'losses': 5,
#  'last_match_time': 1707073781,
#  'name': 'Stereophonics',
#  'tag': 'STPH',
#  'logo_url': 'https://steamusercontent-a.akamaihd.net/ugc/2336873643528563746/DBD2FEC72B30381C07121B1904919A862779DA09/'}

# %%
matches[0].__dict__
# Out:
# {'match_id': 7518239146,
#  'pro_match_data': ProMatchData(match_id=7518239146, radiant_team_id=9229377, dire_team_id=8829924, leagueid=15901, series_type=1, radiant_score=31, dire_score=53, radiant_win=False),
#  'barracks_status_dire': 63,
#  'barracks_status_radiant': 0,
#  'dire_score': 53,
#  'draft_timings': [DraftItem(order=1, pick=False, active_team=2, hero_id=102, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=2, pick=False, active_team=2, hero_id=28, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=3, pick=False, active_team=2, hero_id=53, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=4, pick=False, active_team=2, hero_id=38, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=5, pick=False, active_team=2, hero_id=91, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=6, pick=False, active_team=2, hero_id=100, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=7, pick=False, active_team=2, hero_id=71, player_slot=None, extra_time=130, total_time_taken=0),
#   DraftItem(order=8, pick=True, active_team=2, hero_id=61, player_slot=6, extra_time=130, total_time_taken=0),
#   DraftItem(order=9, pick=True, active_team=2, hero_id=26, player_slot=3, extra_time=93, total_time_taken=12),
#   DraftItem(order=10, pick=False, active_team=3, hero_id=23, player_slot=None, extra_time=93, total_time_taken=26),
#   DraftItem(order=11, pick=False, active_team=3, hero_id=98, player_slot=None, extra_time=124, total_time_taken=13),
#   DraftItem(order=12, pick=False, active_team=2, hero_id=46, player_slot=None, extra_time=124, total_time_taken=3),
#   DraftItem(order=13, pick=True, active_team=2, hero_id=81, player_slot=2, extra_time=93, total_time_taken=2),
#   DraftItem(order=14, pick=True, active_team=3, hero_id=96, player_slot=7, extra_time=93, total_time_taken=3),
#   DraftItem(order=15, pick=True, active_team=3, hero_id=138, player_slot=9, extra_time=124, total_time_taken=17),
#   DraftItem(order=16, pick=True, active_team=2, hero_id=20, player_slot=4, extra_time=121, total_time_taken=33),
#   DraftItem(order=17, pick=True, active_team=2, hero_id=31, player_slot=1, extra_time=93, total_time_taken=62),
#   DraftItem(order=18, pick=True, active_team=3, hero_id=121, player_slot=8, extra_time=93, total_time_taken=16),
#   DraftItem(order=19, pick=False, active_team=3, hero_id=70, player_slot=None, extra_time=89, total_time_taken=33),
#   DraftItem(order=20, pick=False, active_team=2, hero_id=83, player_slot=None, extra_time=89, total_time_taken=8),
#   DraftItem(order=21, pick=False, active_team=2, hero_id=51, player_slot=None, extra_time=91, total_time_taken=5),
#   DraftItem(order=22, pick=False, active_team=3, hero_id=89, player_slot=None, extra_time=33, total_time_taken=88),
#   DraftItem(order=23, pick=True, active_team=3, hero_id=32, player_slot=5, extra_time=89, total_time_taken=2),
#   DraftItem(order=24, pick=True, active_team=2, hero_id=69, player_slot=0, extra_time=89, total_time_taken=21)],
#  'picks_bans': [PickBanItem(is_pick=False, hero_id=91, team=1, order=0, ord=None),
#   PickBanItem(is_pick=False, hero_id=102, team=0, order=1, ord=None),
#   PickBanItem(is_pick=False, hero_id=28, team=0, order=2, ord=None),
#   PickBanItem(is_pick=False, hero_id=100, team=1, order=3, ord=None),
#   PickBanItem(is_pick=False, hero_id=53, team=0, order=4, ord=None),
#   PickBanItem(is_pick=False, hero_id=38, team=0, order=5, ord=None),
#   PickBanItem(is_pick=False, hero_id=71, team=1, order=6, ord=None),
#   PickBanItem(is_pick=True, hero_id=61, team=1, order=7, ord=None),
#   PickBanItem(is_pick=True, hero_id=26, team=0, order=8, ord=None),
#   PickBanItem(is_pick=False, hero_id=23, team=1, order=9, ord=None),
#   PickBanItem(is_pick=False, hero_id=98, team=1, order=10, ord=None),
#   PickBanItem(is_pick=False, hero_id=46, team=0, order=11, ord=None),
#   PickBanItem(is_pick=True, hero_id=81, team=0, order=12, ord=None),
#   PickBanItem(is_pick=True, hero_id=96, team=1, order=13, ord=None),
#   PickBanItem(is_pick=True, hero_id=138, team=1, order=14, ord=None),
#   PickBanItem(is_pick=True, hero_id=20, team=0, order=15, ord=None),
#   PickBanItem(is_pick=True, hero_id=31, team=0, order=16, ord=None),
#   PickBanItem(is_pick=True, hero_id=121, team=1, order=17, ord=None),
#   PickBanItem(is_pick=False, hero_id=70, team=1, order=18, ord=None),
#   PickBanItem(is_pick=False, hero_id=83, team=0, order=19, ord=None),
#   PickBanItem(is_pick=False, hero_id=51, team=0, order=20, ord=None),
#   PickBanItem(is_pick=False, hero_id=89, team=1, order=21, ord=None),
#   PickBanItem(is_pick=True, hero_id=32, team=1, order=22, ord=None),
#   PickBanItem(is_pick=True, hero_id=69, team=0, order=23, ord=None)],
#  'duration': 2011,
#  'first_blood_time': 4,
#  'leagueid': 15901,
#  'objectives': [ObjectiveData(time=4, type='CHAT_MESSAGE_FIRSTBLOOD', unit=None, key=8, slot=0, player_slot=0, value=None, killer=None, team=None),
#   ObjectiveData(time=43, type='CHAT_MESSAGE_COURIER_LOST', unit=None, key=None, slot=None, player_slot=None, value=25, killer=1, team=3),
#   ObjectiveData(time=552, type='building_kill', unit='npc_dota_creep_goodguys_melee', key='npc_dota_badguys_tower1_top', slot=None, player_slot=None, value=None, killer=None, team=None),
#   ObjectiveData(time=610, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower1_mid', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=757, type='CHAT_MESSAGE_COURIER_LOST', unit=None, key=None, slot=None, player_slot=None, value=60, killer=128, team=2),
#   ObjectiveData(time=958, type='CHAT_MESSAGE_COURIER_LOST', unit=None, key=None, slot=None, player_slot=None, value=55, killer=128, team=2),
#   ObjectiveData(time=976, type='building_kill', unit='npc_dota_hero_centaur', key='npc_dota_goodguys_tower1_bot', slot=7, player_slot=130, value=None, killer=None, team=None),
#   ObjectiveData(time=1041, type='building_kill', unit='npc_dota_hero_riki', key='npc_dota_goodguys_tower2_mid', slot=5, player_slot=128, value=None, killer=None, team=None),
#   ObjectiveData(time=1063, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower2_bot', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1145, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower3_bot', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1260, type='CHAT_MESSAGE_ROSHAN_KILL', unit=None, key=None, slot=None, player_slot=None, value=None, killer=None, team=3),
#   ObjectiveData(time=1261, type='CHAT_MESSAGE_AEGIS', unit=None, key=None, slot=5, player_slot=128, value=None, killer=None, team=None),
#   ObjectiveData(time=1287, type='building_kill', unit='npc_dota_goodguys_siege', key='npc_dota_badguys_tower1_mid', slot=None, player_slot=None, value=None, killer=None, team=None),
#   ObjectiveData(time=1315, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_melee_rax_bot', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1319, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_range_rax_bot', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1478, type='building_kill', unit='npc_dota_hero_chaos_knight', key='npc_dota_badguys_tower1_bot', slot=2, player_slot=2, value=None, killer=None, team=None),
#   ObjectiveData(time=1501, type='building_kill', unit='npc_dota_hero_centaur', key='npc_dota_goodguys_tower1_top', slot=7, player_slot=130, value=None, killer=None, team=None),
#   ObjectiveData(time=1533, type='building_kill', unit='npc_dota_hero_muerta', key='npc_dota_goodguys_tower2_top', slot=9, player_slot=132, value=None, killer=None, team=None),
#   ObjectiveData(time=1570, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower3_top', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1596, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_range_rax_top', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1601, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_melee_rax_top', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1806, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower3_mid', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1973, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_melee_rax_mid', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1975, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_range_rax_mid', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=1997, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower4', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=2001, type='building_kill', unit='npc_dota_hero_broodmother', key='npc_dota_goodguys_tower4', slot=6, player_slot=129, value=None, killer=None, team=None),
#   ObjectiveData(time=2011, type='building_kill', unit='npc_dota_creep_badguys_flagbearer', key='npc_dota_goodguys_fort', slot=None, player_slot=None, value=None, killer=None, team=None)],
#  'radiant_gold_adv': [0,
#   640,
#   308,
#   -4,
#   335,
#   381,
#   1436,
#   1494,
#   1652,
#   -502,
#   -365,
#   -2331,
#   -700,
#   -2120,
#   -2055,
#   -1888,
#   -4899,
#   -6663,
#   -7967,
#   -8467,
#   -7108,
#   -6398,
#   -7780,
#   -6286,
#   -3585,
#   -4656,
#   -6704,
#   -8589,
#   -6034,
#   -5831,
#   -6654,
#   -9874,
#   -10636,
#   -15024],
#  'radiant_score': 31,
#  'radiant_win': False,
#  'radiant_xp_adv': [0,
#   -74,
#   -230,
#   -503,
#   -435,
#   -4,
#   505,
#   471,
#   -545,
#   -3075,
#   -3611,
#   -4685,
#   -2855,
#   -4507,
#   -4412,
#   -5113,
#   -9134,
#   -11878,
#   -11564,
#   -12372,
#   -10982,
#   -9644,
#   -11186,
#   -9497,
#   -3852,
#   -6498,
#   -8482,
#   -8463,
#   -5815,
#   -9845,
#   -10850,
#   -17326,
#   -22551,
#   -37051],
#  'teamfights': None,
#  'tower_status_dire': 1974,
#  'tower_status_radiant': 0,
#  'version': 21,
#  'series_id': 838493,
#  'radiant_team': TeamData(tag='DG', name='DemiGods', team_id=9229377, rating=1078.07, wins=108, losses=94, last_match_time=1704210865),
#  'dire_team': TeamData(tag='RoR', name='Rabbits of Revenge', team_id=8829924, rating=1086.9, wins=512, losses=540, last_match_time=1704210865),
#  'players': None,
#  'patch': 54,
#  'throw': None,
#  'comeback': 1652}

# %%
downloader
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 downloader
#
# NameError: name 'downloader' is not defined
